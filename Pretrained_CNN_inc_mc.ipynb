# %% [markdown]
# # Pretrained CNN (INC)

# %%
# !pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp36-none-any.whl size=2976 sha256=24bf4da8f7d43032ca7c7100d9d38c7bf13e74ab09d5908046f534783cd13c5e
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
import import_ipynb
import os
import tensorflow as tf
import numpy as np
import Utils as utils

from tensorflow.keras import models
from tensorflow.keras import layers
from sklearn.utils import class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Data preprocessing

# %%
BATCH_SIZE = 16

# %%
#Get datasets
images, labels = utils.load_training()
images, labels = utils.binarize(images, labels, 'mass_calcification')

# %%
images = utils.rescale(images)
images, labels = utils.shuffle_dataset(images, labels)

# %%
images = [np.stack((images[i],)*3, axis=2) for i in range (len(images))]
images = np.array(images)
utils.properties(images)
# Out:
# Properties:
# Shape: (2676, 150, 150, 3)
# Min: 0.0
# Max: 1.0
# Diff: 1.0
# Type of elements: float64

# %%
data_augmentation = ImageDataGenerator(
    rotation_range=90,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.2,
    )


training_set = data_augmentation.flow(images, labels, seed=123, batch_size=BATCH_SIZE, subset='training')
validation_set = data_augmentation.flow(images, labels, seed=123, batch_size=BATCH_SIZE, subset='validation')

# %%
weights = class_weight.compute_class_weight('balanced', np.unique(labels), labels)
weights = dict(enumerate(weights))
print('Class weights: ', weights)
# Out:
# Class weights:  {0: 1.0985221674876848, 1: 0.9176954732510288}

# %% [markdown]
# ## Training

# %% [markdown]
# ### Network architecture

# %%
inceptionNet = tf.keras.applications.InceptionV3(
    include_top=False, # if include or not the dense layer (last)
    input_shape=(150,150,3))

# %%
model = tf.keras.models.Sequential([
  tf.keras.Model(inputs=inceptionNet.input, outputs=inceptionNet.get_layer('mixed2').output, name="inception"),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(256, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(1, activation='sigmoid')                        
])
model.get_layer("inception").trainable=False
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception (Functional)       (None, 16, 16, 288)       993056
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               37749248
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 38,906,657
# Trainable params: 37,913,601
# Non-trainable params: 993,056
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                     mode='max',
                                     patience=20,
                                     restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('models/inception_mc_16_3.h5',
                                       monitor='val_accuracy',
                                       mode='max',
                                       save_best_only=True)]

                       
history = model.fit(
      training_set,
      epochs=100,
      shuffle=False,
      verbose=1,
      callbacks = callbacks,
      class_weight=weights,
      validation_data=validation_set,
      batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
# 134/134 [==============================] - 17s 114ms/step - loss: 1.2539 - accuracy: 0.5808 - val_loss: 0.4658 - val_accuracy: 0.7682
# Epoch 2/100
# 134/134 [==============================] - 15s 115ms/step - loss: 0.4752 - accuracy: 0.7823 - val_loss: 0.3319 - val_accuracy: 0.8617
# Epoch 3/100
# 134/134 [==============================] - 16s 116ms/step - loss: 0.3962 - accuracy: 0.8166 - val_loss: 0.3307 - val_accuracy: 0.8617
# Epoch 4/100
# 134/134 [==============================] - 15s 111ms/step - loss: 0.3724 - accuracy: 0.8418 - val_loss: 0.3943 - val_accuracy: 0.8336
# Epoch 5/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.3432 - accuracy: 0.8584 - val_loss: 0.2891 - val_accuracy: 0.8748
# Epoch 6/100
# 134/134 [==============================] - 15s 115ms/step - loss: 0.3115 - accuracy: 0.8695 - val_loss: 0.2690 - val_accuracy: 0.8972
# Epoch 7/100
# 134/134 [==============================] - 15s 115ms/step - loss: 0.3198 - accuracy: 0.8777 - val_loss: 0.3595 - val_accuracy: 0.8523
# Epoch 8/100
# 134/134 [==============================] - 15s 111ms/step - loss: 0.3209 - accuracy: 0.8578 - val_loss: 0.2810 - val_accuracy: 0.9028
# Epoch 9/100
# 134/134 [==============================] - 15s 114ms/step - loss: 0.3264 - accuracy: 0.8550 - val_loss: 0.3324 - val_accuracy: 0.8710
# Epoch 10/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.3128 - accuracy: 0.8801 - val_loss: 0.4017 - val_accuracy: 0.8243
# Epoch 11/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.3029 - accuracy: 0.8754 - val_loss: 0.2893 - val_accuracy: 0.9009
# Epoch 12/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.3005 - accuracy: 0.8765 - val_loss: 0.2686 - val_accuracy: 0.8953
# Epoch 13/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2596 - accuracy: 0.8990 - val_loss: 0.3339 - val_accuracy: 0.8692
# Epoch 14/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2697 - accuracy: 0.8895 - val_loss: 0.2492 - val_accuracy: 0.9121
# Epoch 15/100
# 134/134 [==============================] - 15s 113ms/step - loss: 0.2515 - accuracy: 0.9015 - val_loss: 0.3016 - val_accuracy: 0.8935
# Epoch 16/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2765 - accuracy: 0.8851 - val_loss: 0.5628 - val_accuracy: 0.7888
# Epoch 17/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.3095 - accuracy: 0.8639 - val_loss: 0.3326 - val_accuracy: 0.9009
# Epoch 18/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2591 - accuracy: 0.8970 - val_loss: 0.4720 - val_accuracy: 0.8206
# Epoch 19/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2760 - accuracy: 0.8875 - val_loss: 0.2739 - val_accuracy: 0.8991
# Epoch 20/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2790 - accuracy: 0.8890 - val_loss: 0.3881 - val_accuracy: 0.8804
# Epoch 21/100
# 134/134 [==============================] - 14s 107ms/step - loss: 0.2708 - accuracy: 0.8892 - val_loss: 0.3412 - val_accuracy: 0.8654
# Epoch 22/100
# 134/134 [==============================] - 15s 108ms/step - loss: 0.2771 - accuracy: 0.8796 - val_loss: 0.2994 - val_accuracy: 0.8972
# Epoch 23/100
# 134/134 [==============================] - 14s 107ms/step - loss: 0.2401 - accuracy: 0.9049 - val_loss: 0.2398 - val_accuracy: 0.9121
# Epoch 24/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2596 - accuracy: 0.8818 - val_loss: 0.3284 - val_accuracy: 0.8598
# Epoch 25/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2686 - accuracy: 0.8936 - val_loss: 0.3737 - val_accuracy: 0.8785
# Epoch 26/100
# 134/134 [==============================] - 15s 111ms/step - loss: 0.2440 - accuracy: 0.9018 - val_loss: 0.3163 - val_accuracy: 0.8748
# Epoch 27/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2626 - accuracy: 0.8985 - val_loss: 0.2454 - val_accuracy: 0.9215
# Epoch 28/100
# 134/134 [==============================] - 15s 114ms/step - loss: 0.2655 - accuracy: 0.8940 - val_loss: 0.2838 - val_accuracy: 0.9252
# Epoch 29/100
# 134/134 [==============================] - 15s 113ms/step - loss: 0.2751 - accuracy: 0.8903 - val_loss: 0.2325 - val_accuracy: 0.9215
# Epoch 30/100
# 134/134 [==============================] - 15s 108ms/step - loss: 0.2550 - accuracy: 0.8950 - val_loss: 0.2165 - val_accuracy: 0.9140
# Epoch 31/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2272 - accuracy: 0.9053 - val_loss: 0.2968 - val_accuracy: 0.8822
# Epoch 32/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2452 - accuracy: 0.8935 - val_loss: 0.2439 - val_accuracy: 0.9140
# Epoch 33/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2475 - accuracy: 0.9073 - val_loss: 0.3045 - val_accuracy: 0.8879
# Epoch 34/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2483 - accuracy: 0.9028 - val_loss: 0.2239 - val_accuracy: 0.9271
# Epoch 35/100
# 134/134 [==============================] - 15s 113ms/step - loss: 0.2409 - accuracy: 0.9095 - val_loss: 0.2517 - val_accuracy: 0.9047
# Epoch 36/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2408 - accuracy: 0.9010 - val_loss: 0.2614 - val_accuracy: 0.9121
# Epoch 37/100
# 134/134 [==============================] - 15s 108ms/step - loss: 0.2398 - accuracy: 0.9085 - val_loss: 0.2395 - val_accuracy: 0.9178
# Epoch 38/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2293 - accuracy: 0.8992 - val_loss: 0.2909 - val_accuracy: 0.8897
# Epoch 39/100
# 134/134 [==============================] - 14s 108ms/step - loss: 0.2512 - accuracy: 0.9040 - val_loss: 0.2443 - val_accuracy: 0.9084
# Epoch 40/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2225 - accuracy: 0.9090 - val_loss: 0.2690 - val_accuracy: 0.8991
# Epoch 41/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2327 - accuracy: 0.9038 - val_loss: 0.3551 - val_accuracy: 0.8804
# Epoch 42/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2232 - accuracy: 0.9118 - val_loss: 0.4544 - val_accuracy: 0.8262
# Epoch 43/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2259 - accuracy: 0.9078 - val_loss: 0.2826 - val_accuracy: 0.9065
# Epoch 44/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2399 - accuracy: 0.9115 - val_loss: 0.2462 - val_accuracy: 0.9290
# Epoch 45/100
# 134/134 [==============================] - 15s 115ms/step - loss: 0.2315 - accuracy: 0.9086 - val_loss: 0.2474 - val_accuracy: 0.9159
# Epoch 46/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2328 - accuracy: 0.9170 - val_loss: 0.2705 - val_accuracy: 0.8972
# Epoch 47/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2338 - accuracy: 0.9103 - val_loss: 0.2602 - val_accuracy: 0.8860
# Epoch 48/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2388 - accuracy: 0.9038 - val_loss: 0.2129 - val_accuracy: 0.9290
# Epoch 49/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2214 - accuracy: 0.9138 - val_loss: 0.2509 - val_accuracy: 0.9271
# Epoch 50/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2300 - accuracy: 0.9144 - val_loss: 0.2862 - val_accuracy: 0.8972
# Epoch 51/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2247 - accuracy: 0.9100 - val_loss: 0.2515 - val_accuracy: 0.9028
# Epoch 52/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2148 - accuracy: 0.9080 - val_loss: 0.2344 - val_accuracy: 0.9065
# Epoch 53/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2443 - accuracy: 0.9039 - val_loss: 0.2764 - val_accuracy: 0.9103
# Epoch 54/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2033 - accuracy: 0.9263 - val_loss: 0.2745 - val_accuracy: 0.9065
# Epoch 55/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2477 - accuracy: 0.9094 - val_loss: 0.2337 - val_accuracy: 0.9234
# Epoch 56/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2421 - accuracy: 0.9052 - val_loss: 0.2987 - val_accuracy: 0.9103
# Epoch 57/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2448 - accuracy: 0.8951 - val_loss: 0.4314 - val_accuracy: 0.8673
# Epoch 58/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2673 - accuracy: 0.9098 - val_loss: 0.2657 - val_accuracy: 0.9140
# Epoch 59/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2459 - accuracy: 0.9111 - val_loss: 0.2453 - val_accuracy: 0.9271
# Epoch 60/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2259 - accuracy: 0.9200 - val_loss: 0.2667 - val_accuracy: 0.8972
# Epoch 61/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2194 - accuracy: 0.9106 - val_loss: 0.2483 - val_accuracy: 0.9121
# Epoch 62/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2150 - accuracy: 0.9150 - val_loss: 0.3167 - val_accuracy: 0.8972
# Epoch 63/100
# 134/134 [==============================] - 15s 110ms/step - loss: 0.2257 - accuracy: 0.9227 - val_loss: 0.2208 - val_accuracy: 0.9234
# Epoch 64/100
# 134/134 [==============================] - 15s 109ms/step - loss: 0.2208 - accuracy: 0.9173 - val_loss: 0.2416 - val_accuracy: 0.9252

# %% [markdown]
# ### Training plots

# %%
utils.plot_training(history.history['accuracy'], 
                    history.history['loss'], 
                    history.history['val_accuracy'], 
                    history.history['val_loss'], 
                    64,
                    'figures/inception_mc_16_3.png')

# %% [markdown]
# ## Evaluation

# %%
test_images, test_labels = utils.load_test()
test_dataset, test_lab = utils.binarize(test_images, test_labels, 'mass_calcification')
test_dataset = utils.rescale(test_dataset)
test_dataset = [np.stack((test_dataset[i],)*3, axis=2) for i in range (len(test_dataset))]

# %%
test_dataset = np.array(test_dataset)
predicted = model.predict(test_dataset, verbose=1)
predicted = [0 if x <=0.5 else 1 for x in predicted]
utils.evaluate_classifier(test_lab, predicted)

utils.plot_confusion_matrix(test_lab, predicted, ['mass', 'calcification'], 'figures/inception_mc_cm_16_3.png')
# Out:
# 11/11 [==============================] - 1s 20ms/step
# Performances:
# Accuracy:  0.9136904761904762
# Precision:  0.914225785035172
# Recall:  0.9136904761904762
# F1-score:  0.9137556258661076
# AUC:  0.9142974059708928
